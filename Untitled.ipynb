# %%
# !git clone https://github.com/PRESIDENT810/public_cs224n_gpt.git
# Out:
# Cloning into 'public_cs224n_gpt'...
# remote: Enumerating objects: 105, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 105 (delta 38), reused 54 (delta 24), pack-reused 22 (from 2)
# Receiving objects: 100% (105/105), 30.94 MiB | 24.75 MiB/s, done.
# Resolving deltas: 100% (38/38), done.

# %%
# !cd public_cs224n_gpt && python3 classifier.py --fine-tune-mode full-model --batch_size 8 --epochs 10 --lr 1e-5 --hidden_dropout_prob 0.3 --use_gpu
# Out:
# 2025-05-25 20:04:30.065287: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748203470.084791    1673 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748203470.090899    1673 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-25 20:04:30.110518: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
