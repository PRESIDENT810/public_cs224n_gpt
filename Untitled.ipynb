# %%
# !git clone https://github.com/PRESIDENT810/public_cs224n_gpt.git
# Out:
# Cloning into 'public_cs224n_gpt'...
# remote: Enumerating objects: 108, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 108 (delta 39), reused 52 (delta 23), pack-reused 22 (from 2)
# Receiving objects: 100% (108/108), 30.94 MiB | 13.50 MiB/s, done.
# Resolving deltas: 100% (39/39), done.

# %%
# !cd public_cs224n_gpt && git pull
# Out:
# Already up to date.

# %%
# !cd public_cs224n_gpt && python3 classifier.py --fine-tune-mode full-model --batch_size 16 --epochs 10 --lr 1e-5 --hidden_dropout_prob 0.3 --use_gpu
# Out:
# 2025-05-26 02:44:56.449279: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748227496.468985   10375 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748227496.474968   10375 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-26 02:44:56.496005: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
